# %% [markdown]
# <a href="https://colab.research.google.com/github/gupta-bananas/pytorch-deep-learning/blob/main/pytorch_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pytorch as py
import pandas as pd
